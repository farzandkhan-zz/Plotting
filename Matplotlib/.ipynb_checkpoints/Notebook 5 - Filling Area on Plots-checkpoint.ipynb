# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
def dataReader(filename):
    return pd.read_csv(filename, delimiter='\t')
data = dataReader('data/data_filtered.txt')

# %%
data.columns
# Out:
# Index(['Age', 'All_Devs', 'Python', 'JavaScript'], dtype='object')

# %%
def filler():
    ages = data['Age']
    dev_salaries = data['All_Devs']
    py_salaries = data['Python']
    js_salaries = data['JavaScript']
    overall_median = 57287

    plt.plot(ages, dev_salaries, color='#444444', linestyle='--', label='All Devs')
    plt.plot(ages, py_salaries, color='#EC7063', label='Python')
    plt.fill_between(ages, py_salaries, dev_salaries, alpha=0.25, where=(py_salaries>dev_salaries), interpolate=True, label='Above Avg')
    plt.fill_between(ages, py_salaries, dev_salaries, color='#c8abd4', alpha=0.25, where=(py_salaries<=dev_salaries), interpolate=True, label='Below Avg')
    plt.legend()
    plt.grid(True)
    plt.title('Median Salary (USD) by Age')
    plt.xlabel('Ages')
    plt.ylabel('Median Salary (USD)')
    plt.tight_layout()
    plt.savefig('data/Graph.png',dpi=180)
    plt.show()
    
filler()
